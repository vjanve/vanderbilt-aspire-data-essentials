# %%
# import pandas as pd
import pandas as pd
# check current directory with magic command for windows terminal, on mac probably use ls
# !dir
# Out:
#  Volume in drive H is VUSE
#  Volume Serial Number is 009A-9A03
#
#  Directory of H:\DataScience\DataScience_essentials\MaryLvV_git_repo\vanderbilt-aspire-data-essentials\workspace_VJ
#
# 09/14/2018  11:21 AM    <DIR>          .
# 09/12/2018  11:32 AM    <DIR>          ..
# 09/12/2018  11:36 AM    <DIR>          .ipynb_checkpoints
# 09/14/2018  11:21 AM            40,848 DataScience_essentials_week2_vj.ipynb
# 09/12/2018  12:17 PM             1,444 week_two.md
#                2 File(s)         42,292 bytes
#                3 Dir(s)  2,173,426,894,848 bytes free

# %%
# create a DataFrame, hospice_df from hospice CSV
hospice_df = pd.read_csv('..\data\Hospice_General_Information.csv')

# %%
# keep only the rows where facilities are in TN
hospice_TN = hospice_df.loc[hospice_df.State == 'TN']
hospice_TN.head(1)
# Out:
#       CMS Certification Number (CCN)      Facility Name       Address Line 1  \
# 2889                          441501  ALIVE HOSPICE INC  1718 PATTERSON ROAD
#
#       Address Line 2       City State  Zip Code County Name     PhoneNumber  \
# 2889             NaN  NASHVILLE    TN     37203    Davidson  (615) 327-1085
#
#       CMS Region Ownership Type Certification Date
# 2889           4     Non-Profit         04/10/1984

# %%
# examine the column names: used it to copy and modify the list to delete
hospice_TN.columns
# Out:
# Index(['CMS Certification Number (CCN)', 'Facility Name', 'Address Line 1',
#        'Address Line 2', 'City', 'State', 'Zip Code', 'County Name',
#        'PhoneNumber', 'CMS Region', 'Ownership Type', 'Certification Date'],
#       dtype='object')

# %%
# learn usage of drop method on DataFrame : ['Facility Name', 'Address Line 1', 'City', 'State', 'County Name',
#       'CMS Region', 'Ownership Type', 'Certification Date']
# ?hospice_TN.drop

# %%
# keep only the desired columns: notice the dtype is object a default object type
#       -  Keep only the **Facility Name**, **Address Line 1**, **City**, **State**,
#**County Name**, **CMS Region**, **Ownership Type**, and **Cerfification Date** columns.
# drop with keyword axis 
hospice_TN_trunc = hospice_TN.drop(['CMS Certification Number (CCN)', 'Address Line 2', 'Zip Code', 
       'PhoneNumber'], axis =1)

# %%
# Make all column names lower case and without spaces.
# note only removes 1 space; need to use \s+ regex fro better compatibility 
hospice_TN_trunc.columns = hospice_TN_trunc.columns.str.lower().str.replace(' ','')
hospice_TN_trunc.columns
# Out:
# Index(['facilityname', 'addressline1', 'city', 'state', 'countyname',
#        'cmsregion', 'ownershiptype', 'certificationdate'],
#       dtype='object')

# %%
# - Examine the first 5 rows and the last five rows of the TN hospice data.
# note: default for head and tail is 5 rows
hospice_TN_trunc.head(5)
# Out:
#                             facilityname                       addressline1  \
# 2889                   ALIVE HOSPICE INC                1718 PATTERSON ROAD
# 2890          METHODIST ALLIANCE HOSPICE  6400 SHELBY VIEW DRIVE, SUITE 101
# 2891          HOSPICE OF CHATTANOOGA INC                 4411 OAKWOOD DRIVE
# 2892               AMEDISYS HOSPICE CARE          6570 STAGE ROAD SUITE 110
# 2893  NORTHCREST HOME HEALTH AND HOSPICE               212 NORTHCREST DRIVE
#
#              city state countyname  cmsregion ownershiptype certificationdate
# 2889    NASHVILLE    TN   Davidson          4    Non-Profit        04/10/1984
# 2890      MEMPHIS    TN     Shelby          4    Non-Profit        08/31/1984
# 2891  CHATTANOOGA    TN   Hamilton          4    Non-Profit        06/30/1986
# 2892     BARTLETT    TN     Shelby          4    For-Profit        02/09/1987
# 2893  SPRINGFIELD    TN  Robertson          4         Other        07/13/1987

# %%
# the last five rows
hospice_TN_trunc.tail(5)
# Out:
#                               facilityname                   addressline1  \
# 2940        ENCOMPASS HOSPICE OF TENNESSEE    828 ROYAL PARKWAY SUITE 113
# 2941                       QUALITY HOSPICE        341 WEST CENTRAL AVENUE
# 2942                        HEARTH HOSPICE  1800A ROSSVILLE AVE SUITE 114
# 2943  AMEDISYS HOSPICE, AN ADVENTA COMPANY              400 ROYAL PARKWAY
# 2944                       KINDRED HOSPICE        430 STUART RD NE, STE 2
#
#              city state countyname  cmsregion ownershiptype certificationdate
# 2940    NASHVILLE    TN   Davidson          4    For-Profit        06/16/2010
# 2941    JAMESTOWN    TN   Fentress          4    For-Profit        01/04/2013
# 2942  CHATTANOOGA    TN   Hamilton          4    For-Profit        03/22/2013
# 2943    NASHVILLE    TN   Davidson          4         Other        01/05/2016
# 2944    CLEVELAND    TN    Bradley          4    For-Profit        01/04/2017

# %%
# - Print the dimensions of the data. How many hospice facilities are in TN?
# ?hospice_TN_trunc.size # not useful gives row*column for DataFrame
# hospice_TN.ndim # 2 check dimensions
#hospice_TN_trunc.state.count()
#hospice_TN.State.count()
print('The dimension of the data(hospice_TN) is  ' + str(hospice_TN_trunc.shape))
print('# of hospice facilities in TN: ' + str(hospice_TN_trunc.shape[0]))
# Out:
# The dimension of the data(hospice_TN) is  (56, 8)
# # of hospice facilities in TN: 56

# %%
#  * Create a DataFrame, `cancer_df`, from the cancer CSV file.  
#      - Look at the head and tail of the DataFrame.  
#     - Print the shape of the cancer data.  
#     - Keep and rename all columns. 
#     - You can read more about **2020 Healthy People Objective target of 161.4 cancer deaths per 100,000 people** [here](https://www.healthypeople.gov/).
# !dir ..\data\*.csv
# Out:
#  Volume in drive H is VUSE
#  Volume Serial Number is 009A-9A03
#
#  Directory of H:\DataScience\DataScience_essentials\MaryLvV_git_repo\vanderbilt-aspire-data-essentials\data
#
# 09/12/2018  11:11 AM           551,971 PEP_2017_PEPAGESEX.csv
# 09/12/2018  11:11 AM           605,007 Hospice_General_Information.csv
# 09/12/2018  11:11 AM             9,045 cancer_deaths.csv
#                3 File(s)      1,166,023 bytes
#                0 Dir(s)  2,173,426,894,848 bytes free

# %%
# create a DataFrame, cancer_df from cancer CSV
# using r before path name creats raw string avoiding \n, \t, etc to be interpreted as escape characters
# keywords: skiprows, nrows, skipfooter, engine

cancer_df = pd.read_csv(r'..\data\cancer_deaths.csv', skiprows=4, nrows = 98)
# could use  skipfooter=1, engine = 'python' # note some complications using skipfooter in conjuction with nrows 
# and engine conflict when using skipfooter 
#?pd.read_csv
type(cancer_df)
# cancer_df read correctly?
cancer_df
# of 111 rows and 11 columns in dataframe only 0-97 rows is actual data rest is foot notes. 0 th row is headings
# Out:
#                                                County     FIPS  \
# 0                                           Tennessee  47999.0
# 1                                       United States      0.0
# 2                                    Trousdale County  47169.0
# 3                                        Scott County  47151.0
# 4                                     Cheatham County  47021.0
# 5                                    Claiborne County  47025.0
# 6                                      Hancock County  47067.0
# 7                                        Union County  47173.0
# 8                                       Benton County  47005.0
# 9                                      Houston County  47083.0
# 10                                  Sequatchie County  47153.0
# 11                                       Cocke County  47029.0
# 12                                    Grainger County  47057.0
# 13                                     Carroll County  47017.0
# 14                                        Lake County  47095.0
# 15                                    Campbell County  47013.0
# 16                                     Stewart County  47161.0
# 17                                     Overton County  47133.0
# 18                                      Marion County  47115.0
# 19                                       White County  47185.0
# 20                                       Perry County  47135.0
# 21                                     Johnson County  47091.0
# 22                                       Meigs County  47121.0
# 23                                       Obion County  47131.0
# 24                                   Humphreys County  47085.0
# 25                                       Macon County  47111.0
# 26                                    Fentress County  47049.0
# 27                                      Grundy County  47061.0
# 28                                      Tipton County  47167.0
# 29                                        Polk County  47139.0
# ..                                                ...      ...
# 68                                     Bradley County  47011.0
# 69                                        Dyer County  47045.0
# 70                                     Bedford County  47003.0
# 71                                    Sullivan County  47163.0
# 72                                       Maury County  47119.0
# 73                                     Lincoln County  47103.0
# 74                                      Morgan County  47129.0
# 75                                    Anderson County  47001.0
# 76                                  Washington County  47179.0
# 77                                      DeKalb County  47041.0
# 78                                     Chester County  47023.0
# 79                                        Knox County  47093.0
# 80                                      Carter County  47019.0
# 81                                  Cumberland County  47035.0
# 82                                      Loudon County  47105.0
# 83                                    Hamilton County  47065.0
# 84                                     Madison County  47113.0
# 85                                      Wilson County  47189.0
# 86                                  Rutherford County  47149.0
# 87                                     Bledsoe County  47007.0
# 88                                   Jefferson County  47089.0
# 89                                      Blount County  47009.0
# 90                                    Crockett County  47033.0
# 91                                      Sumner County  47165.0
# 92                                   Van Buren County  47175.0
# 93                                     Pickett County  47137.0
# 94                                     Fayette County  47047.0
# 95                                  Williamson County  47187.0
# 96                                       Moore County  47127.0
# 97  Created by statecancerprofiles.cancer.gov on 0...      NaN
#
#    Met Healthy People Objective of 161.4?  \
# 0                                      No
# 1                                      No
# 2                                      No
# 3                                      No
# 4                                      No
# 5                                      No
# 6                                      No
# 7                                      No
# 8                                      No
# 9                                      No
# 10                                     No
# 11                                     No
# 12                                     No
# 13                                     No
# 14                                     No
# 15                                     No
# 16                                     No
# 17                                     No
# 18                                     No
# 19                                     No
# 20                                     No
# 21                                     No
# 22                                     No
# 23                                     No
# 24                                     No
# 25                                     No
# 26                                     No
# 27                                     No
# 28                                     No
# 29                                     No
# ..                                    ...
# 68                                     No
# 69                                     No
# 70                                     No
# 71                                     No
# 72                                     No
# 73                                     No
# 74                                     No
# 75                                     No
# 76                                     No
# 77                                     No
# 78                                     No
# 79                                     No
# 80                                     No
# 81                                     No
# 82                                     No
# 83                                     No
# 84                                     No
# 85                                     No
# 86                                     No
# 87                                     No
# 88                                     No
# 89                                     No
# 90                                     No
# 91                                    Yes
# 92                                    Yes
# 93                                    Yes
# 94                                    Yes
# 95                                    Yes
# 96                                    Yes
# 97                                    NaN
#
#     Age-Adjusted Death Rate - deaths per 100,000  \
# 0                                          185.4
# 1                                          163.5
# 2                                          265.5
# 3                                          241.0
# 4                                          239.6
# 5                                          237.3
# 6                                          236.2
# 7                                          234.2
# 8                                          233.9
# 9                                          227.4
# 10                                         224.3
# 11                                         222.1
# 12                                         222.0
# 13                                         221.8
# 14                                         220.4
# 15                                         219.2
# 16                                         218.2
# 17                                         217.0
# 18                                         216.7
# 19                                         216.3
# 20                                         216.0
# 21                                         215.8
# 22                                         214.3
# 23                                         214.1
# 24                                         212.3
# 25                                         211.5
# 26                                         211.1
# 27                                         210.7
# 28                                         210.6
# 29                                         209.5
# ..                                           ...
# 68                                         183.0
# 69                                         182.9
# 70                                         182.7
# 71                                         181.4
# 72                                         181.1
# 73                                         181.0
# 74                                         180.7
# 75                                         180.6
# 76                                         180.5
# 77                                         178.8
# 78                                         178.4
# 79                                         177.4
# 80                                         176.2
# 81                                         174.4
# 82                                         173.9
# 83                                         172.6
# 84                                         171.0
# 85                                         170.5
# 86                                         170.3
# 87                                         170.0
# 88                                         169.1
# 89                                         168.2
# 90                                         164.1
# 91                                         161.2
# 92                                         160.3
# 93                                         158.7
# 94                                         154.3
# 95                                         127.2
# 96                                         123.2
# 97                                           NaN
#
#     Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                           184.0                          186.8
# 1                           163.3                          163.7
# 2                           219.0                          319.1
# 3                           214.5                          270.0
# 4                           217.8                          263.0
# 5                           216.4                          259.8
# 6                           193.1                          287.1
# 7                           206.1                          265.3
# 8                           207.1                          263.6
# 9                           188.9                          272.1
# 10                          194.3                          257.9
# 11                          203.5                          242.2
# 12                          197.9                          248.4
# 13                          201.2                          244.1
# 14                          178.3                          270.1
# 15                          201.8                          237.7
# 16                          188.3                          252.0
# 17                          193.8                          242.4
# 18                          195.8                          239.4
# 19                          195.1                          239.4
# 20                          178.5                          259.9
# 21                          190.6                          243.8
# 22                          181.7                          251.5
# 23                          194.6                          235.2
# 24                          187.3                          240.1
# 25                          187.3                          238.1
# 26                          185.3                          239.8
# 27                          181.5                          243.6
# 28                          194.5                          227.6
# 29                          183.6                          238.4
# ..                            ...                            ...
# 68                          172.2                          194.3
# 69                          165.7                          201.4
# 70                          166.1                          200.6
# 71                          173.6                          189.5
# 72                          169.1                          193.7
# 73                          163.6                          200.0
# 74                          158.0                          206.0
# 75                          169.1                          192.7
# 76                          171.1                          190.3
# 77                          155.4                          204.9
# 78                          153.5                          206.5
# 79                          172.1                          182.8
# 80                          163.4                          189.9
# 81                          162.5                          187.0
# 82                          160.9                          187.9
# 83                          167.0                          178.3
# 84                          160.3                          182.4
# 85                          160.4                          181.0
# 86                          162.5                          178.4
# 87                          143.5                          200.6
# 88                          155.6                          183.6
# 89                          159.4                          177.4
# 90                          139.1                          192.7
# 91                          153.0                          169.6
# 92                          122.7                          207.4
# 93                          123.3                          203.9
# 94                          139.1                          170.7
# 95                          119.8                          134.9
# 96                           93.9                          160.5
# 97                            NaN                            NaN
#
#     Average Annual Count Recent Trend  Recent 5-Year Trend in Death Rates  \
# 0                13933.0      falling                                -1.4
# 1               586354.0      falling                                -1.5
# 2                   24.0       stable                                 0.0
# 3                   63.0       stable                                -0.5
# 4                   97.0       stable                                -0.6
# 5                  100.0       stable                                -0.1
# 6                   22.0       stable                                 0.4
# 7                   53.0       stable                                -0.5
# 8                   59.0       stable                                 0.3
# 9                   26.0       stable                                 0.4
# 10                  43.0       rising                                 1.3
# 11                 110.0       stable                                -0.5
# 12                  66.0       stable                                 0.1
# 13                  89.0       stable                                -0.2
# 14                  19.0       stable                                -0.3
# 15                 124.0       stable                                -0.4
# 16                  40.0       stable                                 0.1
# 17                  67.0       stable                                -0.3
# 18                  83.0       stable                                -0.4
# 19                  79.0       stable                                -0.6
# 20                  25.0       stable                                 0.0
# 21                  55.0       stable                                 0.1
# 22                  34.0       stable                                 0.5
# 23                  92.0       stable                                 0.0
# 24                  54.0       stable                                -0.2
# 25                  57.0       stable                                -0.2
# 26                  52.0       stable                                -0.5
# 27                  40.0       stable                                 0.5
# 28                 134.0       stable                                -0.2
# 29                  50.0       stable                                -0.8
# ..                   ...          ...                                 ...
# 68                 220.0      falling                                -1.0
# 69                  86.0      falling                                -0.6
# 70                  92.0      falling                                -0.7
# 71                 425.0      falling                                -0.7
# 72                 178.0      falling                                -1.0
# 73                  82.0      falling                                -1.0
# 74                  48.0       stable                                -0.8
# 75                 195.0      falling                                -0.7
# 76                 284.0      falling                                -1.2
# 77                  44.0       stable                                -0.6
# 78                  38.0       stable                                -0.4
# 79                 890.0      falling                                -1.0
# 80                 145.0      falling                                -1.0
# 81                 182.0      falling                                -0.8
# 82                 144.0      falling                                -1.2
# 83                 743.0       stable                                 0.1
# 84                 194.0      falling                                -1.0
# 85                 229.0      falling                                -2.0
# 86                 380.0      falling                                -1.4
# 87                  31.0      falling                                -1.3
# 88                 121.0      falling                                -4.0
# 89                 283.0      falling                                -0.9
# 90                  31.0       stable                                -0.5
# 91                 305.0      falling                                -2.2
# 92                  14.0       stable                                -0.9
# 93                  15.0       stable                                -0.5
# 94                  81.0      falling                                -1.4
# 95                 239.0      falling                                -3.8
# 96                  12.0      falling                                -2.1
# 97                   NaN          NaN                                 NaN
#
#     Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 0                              -1.5                             -1.2
# 1                              -1.6                             -1.5
# 2                              -1.3                              1.3
# 3                              -1.1                              0.1
# 4                              -1.4                              0.3
# 5                              -0.7                              0.4
# 6                              -0.8                              1.6
# 7                              -1.2                              0.2
# 8                              -0.4                              1.1
# 9                              -0.6                              1.3
# 10                              0.3                              2.3
# 11                             -1.0                              0.0
# 12                             -0.7                              1.0
# 13                             -0.7                              0.2
# 14                             -1.4                              0.8
# 15                             -0.8                              0.0
# 16                             -1.2                              1.4
# 17                             -1.1                              0.5
# 18                             -1.1                              0.3
# 19                             -1.3                              0.0
# 20                             -1.4                              1.5
# 21                             -0.8                              1.1
# 22                             -0.8                              1.9
# 23                             -0.5                              0.6
# 24                             -0.9                              0.5
# 25                             -0.7                              0.4
# 26                             -1.2                              0.3
# 27                             -0.6                              1.6
# 28                             -0.8                              0.3
# 29                             -1.9                              0.3
# ..                              ...                              ...
# 68                             -1.4                             -0.5
# 69                             -1.1                             -0.1
# 70                             -1.4                             -0.1
# 71                             -1.1                             -0.4
# 72                             -1.6                             -0.5
# 73                             -1.6                             -0.3
# 74                             -1.7                              0.0
# 75                             -1.2                             -0.2
# 76                             -1.6                             -0.8
# 77                             -1.4                              0.3
# 78                             -1.5                              0.8
# 79                             -1.2                             -0.8
# 80                             -1.6                             -0.4
# 81                             -1.3                             -0.3
# 82                             -1.7                             -0.7
# 83                             -1.5                              1.8
# 84                             -1.4                             -0.5
# 85                             -2.8                             -1.2
# 86                             -1.7                             -1.1
# 87                             -2.3                             -0.3
# 88                             -7.0                             -1.0
# 89                             -1.3                             -0.4
# 90                             -1.3                              0.4
# 91                             -3.6                             -0.8
# 92                             -2.4                              0.6
# 93                             -1.8                              0.9
# 94                             -2.2                             -0.5
# 95                             -4.8                             -2.9
# 96                             -3.8                             -0.4
# 97                              NaN                              NaN
#
# [98 rows x 11 columns]

# %%
# read columns
cancer_column_df = pd.read_csv(r'..\data\cancer_deaths.csv', skiprows=3, nrows = 1)
#Q index_col = 0 sets 0th column as label, did not find keyworkd for row labels: ask?
cancer_column_df
# Out:
#   Sorted by Rate Unnamed: 1                              Unnamed: 2  \
# 0         County       FIPS  Met Healthy People Objective of 161.4?
#
#                                      Unnamed: 3  \
# 0  Age-Adjusted Death Rate - deaths per 100,000
#
#                       Unnamed: 4                     Unnamed: 5  \
# 0  Lower 95% Confidence Interval  Upper 95% Confidence Interval
#
#              Unnamed: 6    Unnamed: 7                          Unnamed: 8  \
# 0  Average Annual Count  Recent Trend  Recent 5-Year Trend in Death Rates
#
#                       Unnamed: 9                    Unnamed: 10
# 0  Lower 95% Confidence Interval  Upper 95% Confidence Interval

# %%
##      - Look at the head and tail of the DataFrame.
print(cancer_df.head())
print(cancer_df.tail())
#     - Print the shape of the cancer data. 
print('shape of cancerDataFrame: ' + str(cancer_df.shape))
# cancer_df.shape() : error tuple object not callable ; cancer_df.shape OK: shape a method not function?
# Out:
#              County     FIPS Met Healthy People Objective of 161.4?  \
# 0         Tennessee  47999.0                                     No
# 1     United States      0.0                                     No
# 2  Trousdale County  47169.0                                     No
# 3      Scott County  47151.0                                     No
# 4   Cheatham County  47021.0                                     No
#
#    Age-Adjusted Death Rate - deaths per 100,000  \
# 0                                         185.4
# 1                                         163.5
# 2                                         265.5
# 3                                         241.0
# 4                                         239.6
#
#    Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                          184.0                          186.8
# 1                          163.3                          163.7
# 2                          219.0                          319.1
# 3                          214.5                          270.0
# 4                          217.8                          263.0
#
#    Average Annual Count Recent Trend  Recent 5-Year Trend in Death Rates  \
# 0               13933.0      falling                                -1.4
# 1              586354.0      falling                                -1.5
# 2                  24.0       stable                                 0.0
# 3                  63.0       stable                                -0.5
# 4                  97.0       stable                                -0.6
#
#    Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 0                             -1.5                             -1.2
# 1                             -1.6                             -1.5
# 2                             -1.3                              1.3
# 3                             -1.1                              0.1
# 4                             -1.4                              0.3
#                                                County     FIPS  \
# 93                                     Pickett County  47137.0
# 94                                     Fayette County  47047.0
# 95                                  Williamson County  47187.0
# 96                                       Moore County  47127.0
# 97  Created by statecancerprofiles.cancer.gov on 0...      NaN
#
#    Met Healthy People Objective of 161.4?  \
# 93                                    Yes
# 94                                    Yes
# 95                                    Yes
# 96                                    Yes
# 97                                    NaN
#
#     Age-Adjusted Death Rate - deaths per 100,000  \
# 93                                         158.7
# 94                                         154.3
# 95                                         127.2
# 96                                         123.2
# 97                                           NaN
#
#     Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 93                          123.3                          203.9
# 94                          139.1                          170.7
# 95                          119.8                          134.9
# 96                           93.9                          160.5
# 97                            NaN                            NaN
#
#     Average Annual Count Recent Trend  Recent 5-Year Trend in Death Rates  \
# 93                  15.0       stable                                -0.5
# 94                  81.0      falling                                -1.4
# 95                 239.0      falling                                -3.8
# 96                  12.0      falling                                -2.1
# 97                   NaN          NaN                                 NaN
#
#     Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 93                             -1.8                              0.9
# 94                             -2.2                             -0.5
# 95                             -4.8                             -2.9
# 96                             -3.8                             -0.4
# 97                              NaN                              NaN
# shape of cancerDataFrame: (98, 11)

# %%
#  Keep and rename all columns.
print(cancer_df.columns)
# output of following command is better than print
cancer_df.head(1)
cancer_df.columns = ['county', 'FIPS', 'Healthy People(>161.4)', 'age adjusted death rate(DR)', 'LCI 95%', 'UCI 95%',
                     'Avg annual count', 'recent trend', 'recent 5yr trend in DR', 'LCI 95%','UCI 95%']
cancer_df.columns
# Out:
# Index(['County', ' FIPS', 'Met Healthy People Objective of 161.4?',
#        'Age-Adjusted Death Rate - deaths per 100,000',
#        'Lower 95% Confidence Interval', 'Upper 95% Confidence Interval',
#        'Average Annual Count', 'Recent Trend',
#        'Recent 5-Year Trend in Death Rates', 'Lower 95% Confidence Interval.1',
#        'Upper 95% Confidence Interval.1'],
#       dtype='object')
# Index(['county', 'FIPS', 'Healthy People(>161.4)',
#        'age adjusted death rate(DR)', 'LCI 95%', 'UCI 95%', 'Avg annual count',
#        'recent trend', 'recent 5yr trend in DR', 'LCI 95%', 'UCI 95%'],
#       dtype='object')

# %%
# need to figure out how to open csv in text editor
# nano('..\data\cancer_deaths.csv')
# work on indexing the dataframe

# %%
#Create a DataFrame, `pop_df`, from the census CSV file.  
#      -  Look at the head and the tail
#- Print the shape  
pop_df = pd.read_csv(r'..\data\PEP_2017_PEPAGESEX.csv')
pop_df.head()
# Out:
#            GEO.id GEO.id2           GEO.display-label  \
# 0              Id     Id2                   Geography
# 1  0500000US47001   47001  Anderson County, Tennessee
# 2  0500000US47003   47003   Bedford County, Tennessee
# 3  0500000US47005   47005    Benton County, Tennessee
# 4  0500000US47007   47007   Bledsoe County, Tennessee
#
#                           cen42010sex0_age999  \
# 0  April 1, 2010 - Census - Both Sexes; Total
# 1                                       75129
# 2                                       45058
# 3                                       16489
# 4                                       12876
#
#                     cen42010sex1_age999  \
# 0  April 1, 2010 - Census - Male; Total
# 1                                 36308
# 2                                 22357
# 3                                  8073
# 4                                  6964
#
#                       cen42010sex2_age999  \
# 0  April 1, 2010 - Census - Female; Total
# 1                                   38821
# 2                                   22701
# 3                                    8416
# 4                                    5912
#
#                                  est42010sex0_age999  \
# 0  April 1, 2010 - Estimates Base - Both Sexes; T...
# 1                                              75094
# 2                                              45056
# 3                                              16491
# 4                                              12872
#
#                             est42010sex1_age999  \
# 0  April 1, 2010 - Estimates Base - Male; Total
# 1                                         36288
# 2                                         22356
# 3                                          8074
# 4                                          6962
#
#                               est42010sex2_age999  \
# 0  April 1, 2010 - Estimates Base - Female; Total
# 1                                           38806
# 2                                           22700
# 3                                            8417
# 4                                            5910
#
#                                  est72010sex0_age999  \
# 0  Population Estimate (as of July 1) - 2010 - Bo...
# 1                                              75112
# 2                                              45086
# 3                                              16511
# 4                                              12882
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                  est72014sex2_medage  \
# 0  Population Estimate (as of July 1) - 2014 - Fe...
# 1                                               44.8
# 2                                               38.4
# 3                                               48.3
# 4                                               46.3
#
#                                  est72015sex0_medage  \
# 0  Population Estimate (as of July 1) - 2015 - Bo...
# 1                                               43.3
# 2                                               37.2
# 3                                               46.6
# 4                                               43.4
#
#                                  est72015sex1_medage  \
# 0  Population Estimate (as of July 1) - 2015 - Ma...
# 1                                               41.4
# 2                                               35.9
# 3                                               45.2
# 4                                               41.7
#
#                                  est72015sex2_medage  \
# 0  Population Estimate (as of July 1) - 2015 - Fe...
# 1                                               44.8
# 2                                               38.5
# 3                                               48.0
# 4                                               46.5
#
#                                  est72016sex0_medage  \
# 0  Population Estimate (as of July 1) - 2016 - Bo...
# 1                                               43.3
# 2                                               37.5
# 3                                               47.1
# 4                                               43.5
#
#                                  est72016sex1_medage  \
# 0  Population Estimate (as of July 1) - 2016 - Ma...
# 1                                               41.5
# 2                                               36.2
# 3                                               45.7
# 4                                               41.9
#
#                                  est72016sex2_medage  \
# 0  Population Estimate (as of July 1) - 2016 - Fe...
# 1                                               45.1
# 2                                               38.8
# 3                                               48.4
# 4                                               46.4
#
#                                  est72017sex0_medage  \
# 0  Population Estimate (as of July 1) - 2017 - Bo...
# 1                                               43.2
# 2                                               37.5
# 3                                               47.4
# 4                                               43.9
#
#                                  est72017sex1_medage  \
# 0  Population Estimate (as of July 1) - 2017 - Ma...
# 1                                               41.2
# 2                                               36.2
# 3                                               46.0
# 4                                               42.1
#
#                                  est72017sex2_medage
# 0  Population Estimate (as of July 1) - 2017 - Fe...
# 1                                               45.0
# 2                                               38.9
# 3                                               48.7
# 4                                               47.3
#
# [5 rows x 993 columns]

# %%
pop_df.tail()
# Out:
#             GEO.id GEO.id2             GEO.display-label cen42010sex0_age999  \
# 91  0500000US47181   47181       Wayne County, Tennessee               17021
# 92  0500000US47183   47183     Weakley County, Tennessee               35021
# 93  0500000US47185   47185       White County, Tennessee               25841
# 94  0500000US47187   47187  Williamson County, Tennessee              183182
# 95  0500000US47189   47189      Wilson County, Tennessee              113993
#
#    cen42010sex1_age999 cen42010sex2_age999 est42010sex0_age999  \
# 91                9402                7619               17027
# 92               17159               17862               35015
# 93               12640               13201               25836
# 94               89336               93846              183252
# 95               55834               58159              114057
#
#    est42010sex1_age999 est42010sex2_age999 est72010sex0_age999  \
# 91                9404                7623               16987
# 92               17157               17858               35042
# 93               12637               13199               25821
# 94               89371               93881              184130
# 95               55863               58194              114677
#
#            ...         est72014sex2_medage est72015sex0_medage  \
# 91         ...                        45.8                42.6
# 92         ...                        39.2                37.6
# 93         ...                        44.0                42.7
# 94         ...                        39.7                39.0
# 95         ...                        41.1                40.2
#
#    est72015sex1_medage est72015sex2_medage est72016sex0_medage  \
# 91                39.8                46.5                42.7
# 92                36.0                39.2                37.9
# 93                41.0                44.2                42.8
# 94                38.2                39.7                39.0
# 95                39.2                41.1                40.0
#
#    est72016sex1_medage est72016sex2_medage est72017sex0_medage  \
# 91                39.9                46.7                43.1
# 92                36.2                39.6                38.3
# 93                41.2                44.3                42.8
# 94                38.3                39.7                39.0
# 95                39.0                40.9                39.9
#
#    est72017sex1_medage est72017sex2_medage
# 91                40.0                47.4
# 92                36.6                40.1
# 93                41.3                44.4
# 94                38.3                39.7
# 95                39.0                40.8
#
# [5 rows x 993 columns]

# %%
# shape
print('the shape of population data frame: '+str(pop_df.shape))
# Out:
# the shape of population data frame: (96, 993)

# %%
# index, column, values
# index = row_labels = row_names; column labels =  column names
# values = data 
# axis = dimension, Axes; axis[0] = row; axis[1] = columns
# referencing by position or name
# indexing = subset selection 
# indexing by [], .loc[], .iloc[]
col_label = pop_df.columns.str.replace
col_label
# ?pd.read_csv
